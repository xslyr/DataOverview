# %%
import pandas as pd
import dfview as vw  # <--- our package

df = pd.read_csv('data.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.describe()

# %% [markdown]
# #### Initializing our DataOverview object linking to "my_describe" variable

# %%
my_describe = vw.DataOverview(df)

my_describe.details
# Out:
# teste...
#              Id MSSubClass MSZoning LotFrontage   LotArea  Street   Alley  \
# dtype     int64      int64   object     float64     int64  object  object
# count      1460       1460     1460        1201      1460    1460      91
# null          0          0        0         259         0       0    1369
# min         1.0       20.0      0.0        21.0    1300.0     0.0     0.0
# mean      730.5       56.9      0.0       70.05  10516.83     0.0     0.0
# max      1460.0      190.0      0.0       313.0  215245.0     0.0     0.0
# median    730.5       50.0      0.0        69.0    9478.5     0.0     0.0
# std      421.61       42.3      0.0       24.28   9981.26     0.0     0.0
# std%       28.9      24.88      0.0        8.32      4.67     0.0     0.0
# 25%      365.75       20.0      0.0        59.0    7553.5     0.0     0.0
# 50%       730.5       50.0      0.0        69.0    9478.5     0.0     0.0
# ...

# %% [markdown]
# #### Printing of column's type distributions

# %%
my_describe.columns_type()
# Out:
# {'int64': 35, 'float64': 3, 'object': 43, 'bool': 0, 'datetime64': 0}

# %% [markdown]
# #### Printing our describe data for float columns

# %%
my_describe.show('float64')

# %% [markdown]
# #### Printing our describe data for object columns

# %%
my_describe.show('object')

# %% [markdown]
# #### Showing the data distribution of a column list

# %%
my_describe.obj_distrib(column_list=['MSZoning','Street','Alley','LotShape','LandContour'])

# %%
my_describe.obj_distrib(column_list=['MSZoning','Street','Alley','LotShape','LandContour'], axis=0)

# %%
my_describe.obj_distrib(column_list=['MSZoning','Street','Alley','LotShape','LandContour'], 
                        axis=0, include_nulls=False)

# %% [markdown]
# The axis with numbers is used to count how many occurence of each data type at that column.
# If parameter include_nulls = False, the column 0 will be hide.

# %%
my_describe.obj_distrib(axis=0, include_nulls=False)
